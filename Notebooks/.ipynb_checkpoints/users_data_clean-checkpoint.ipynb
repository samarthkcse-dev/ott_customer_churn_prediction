# %%
import pandas as pd

# %%
df= pd.read_csv("C:/Users/samar/Desktop/samarth15/OTT platform customer churn prediction/Data/users.csv")

# %%
df.head()
# Out:
#       user_id                      email first_name last_name   age  gender  \
# 0  user_00001   figueroajohn@example.org      Erica     Garza  43.0    Male
# 1  user_00002      blakeerik@example.com     Joshua   Bernard  38.0    Male
# 2  user_00003        smiller@example.net    Barbara  Williams  32.0  Female
# 3  user_00004  mitchellclark@example.com    Chelsea  Ferguson  11.0    Male
# 4  user_00005      richard13@example.net      Jason    Foster  21.0  Female
#
#   country state_province                city subscription_plan  \
# 0     USA  Massachusetts  North Jefferyhaven             Basic
# 1     USA          Texas      North Noahstad          Premium+
# 2     USA       Michigan          Traciebury          Standard
# 3     USA           Ohio          South Noah          Standard
# 4     USA        Arizona         West Donald          Standard
#
#   subscription_start_date  is_active  monthly_spend primary_device  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10300 entries, 0 to 10299
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  10300 non-null  object
#  1   email                    10300 non-null  object
#  2   first_name               10300 non-null  object
#  3   last_name                10300 non-null  object
#  4   age                      9071 non-null   float64
#  5   gender                   9476 non-null   object
#  6   country                  10300 non-null  object
#  7   state_province           10300 non-null  object
#  8   city                     10300 non-null  object
#  9   subscription_plan        10300 non-null  object
#  10  subscription_start_date  10300 non-null  object
#  11  is_active                10300 non-null  bool
#  12  monthly_spend            9283 non-null   float64
#  13  primary_device           10300 non-null  object
# ...

# %% [markdown]
# df.describe()

# %% [markdown]
# Handling Missing Values

# %%
df["age"].isnull().sum()
# Out:
# np.int64(1229)

# %%
med=df["age"].median()
#print(med)
df["age"]=df["age"].fillna(med)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10300 entries, 0 to 10299
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  10300 non-null  object
#  1   email                    10300 non-null  object
#  2   first_name               10300 non-null  object
#  3   last_name                10300 non-null  object
#  4   age                      10300 non-null  float64
#  5   gender                   9476 non-null   object
#  6   country                  10300 non-null  object
#  7   state_province           10300 non-null  object
#  8   city                     10300 non-null  object
#  9   subscription_plan        10300 non-null  object
#  10  subscription_start_date  10300 non-null  object
#  11  is_active                10300 non-null  bool
#  12  monthly_spend            9283 non-null   float64
#  13  primary_device           10300 non-null  object
# ...

# %%
df["age"]=df["age"].astype(in)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10300 entries, 0 to 10299
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  10300 non-null  object
#  1   email                    10300 non-null  object
#  2   first_name               10300 non-null  object
#  3   last_name                10300 non-null  object
#  4   age                      10300 non-null  int64
#  5   gender                   9476 non-null   object
#  6   country                  10300 non-null  object
#  7   state_province           10300 non-null  object
#  8   city                     10300 non-null  object
#  9   subscription_plan        10300 non-null  object
#  10  subscription_start_date  10300 non-null  object
#  11  is_active                10300 non-null  bool
#  12  monthly_spend            9283 non-null   float64
#  13  primary_device           10300 non-null  object
# ...

# %%
df.loc[25:35,"age"]
# Out:
# 25    60
# 26    37
# 27    35
# 28    28
# 29    24
# 30    26
# 31    56
# 32    60
# 33    32
# 34    31
# 35    36
# Name: age, dtype: int64

# %% [markdown]
# Removing Rows with null gender

# %%
df=df.dropna(subset=["gender"])

# %%
df.info()
#df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9476 entries, 0 to 10299
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  9476 non-null   object
#  1   email                    9476 non-null   object
#  2   first_name               9476 non-null   object
#  3   last_name                9476 non-null   object
#  4   age                      9476 non-null   int64
#  5   gender                   9476 non-null   object
#  6   country                  9476 non-null   object
#  7   state_province           9476 non-null   object
#  8   city                     9476 non-null   object
#  9   subscription_plan        9476 non-null   object
#  10  subscription_start_date  9476 non-null   object
#  11  is_active                9476 non-null   bool
#  12  monthly_spend            8551 non-null   float64
#  13  primary_device           9476 non-null   object
# ...

# %%
df.head(15)
# Out:
#        user_id                        email first_name  last_name  age  \
# 0   user_00001     figueroajohn@example.org      Erica      Garza   43
# 1   user_00002        blakeerik@example.com     Joshua    Bernard   38
# 2   user_00003          smiller@example.net    Barbara   Williams   32
# 3   user_00004    mitchellclark@example.com    Chelsea   Ferguson   11
# 4   user_00005        richard13@example.net      Jason     Foster   21
# 5   user_00006        jeffrey28@example.com    Katelyn  Hernandez   43
# 7   user_00008  nathanielmartin@example.net      Carol      Smith   35
# 8   user_00009      donnaarroyo@example.org    Allison     Brandt   24
# 9   user_00010    morganbrianna@example.org     Adrian      Perez   24
# 10  user_00011   kristenaguirre@example.org     Collin      Gomez   67
# 11  user_00012     jamesherrera@example.org     Isaiah     Wright   41
# 12  user_00013     richardolson@example.com   Franklin   Galloway   32
# ...

# %%
df=df.rename(columns={"monthly_spend":"Monthly_Charge"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9476 entries, 0 to 10299
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  9476 non-null   object
#  1   email                    9476 non-null   object
#  2   first_name               9476 non-null   object
#  3   last_name                9476 non-null   object
#  4   age                      9476 non-null   int64
#  5   gender                   9476 non-null   object
#  6   country                  9476 non-null   object
#  7   state_province           9476 non-null   object
#  8   city                     9476 non-null   object
#  9   subscription_plan        9476 non-null   object
#  10  subscription_start_date  9476 non-null   object
#  11  is_active                9476 non-null   bool
#  12  Monthly_Charge           8734 non-null   float64
#  13  primary_device           9476 non-null   object
# ...

# %%
df.loc[df["subscription_plan"]=="Basic","Monthly_Charge"]=9.99

# %%
df.loc[df["subscription_plan"]=="Basic","Monthly_Charge"]
# Out:
# 0        9.99
# 7        9.99
# 9        9.99
# 10       9.99
# 12       9.99
#          ...
# 10289    9.99
# 10290    9.99
# 10294    9.99
# 10296    9.99
# 10298    9.99
# Name: Monthly_Charge, Length: 1858, dtype: float64

# %%
df.loc[df["subscription_plan"]=="Standard","Monthly_Charge"]=15.99

# %%
df.loc[df["subscription_plan"]=="Premium","Monthly_Charge"]=21.99

# %%
df.loc[df["subscription_plan"]=="Premium+","Monthly_Charge"]=29.99

# %%
df=df.rename(columns={"monthly_spend":"Monthly_Charge_$)"})

# %%
df.head()
# Out:
#       user_id                      email first_name last_name  age  gender  \
# 0  user_00001   figueroajohn@example.org      Erica     Garza   43    Male
# 1  user_00002      blakeerik@example.com     Joshua   Bernard   38    Male
# 2  user_00003        smiller@example.net    Barbara  Williams   32  Female
# 3  user_00004  mitchellclark@example.com    Chelsea  Ferguson   11    Male
# 4  user_00005      richard13@example.net      Jason    Foster   21  Female
#
#   country state_province                city subscription_plan  \
# 0     USA  Massachusetts  North Jefferyhaven             Basic
# 1     USA          Texas      North Noahstad          Premium+
# 2     USA       Michigan          Traciebury          Standard
# 3     USA           Ohio          South Noah          Standard
# 4     USA        Arizona         West Donald          Standard
#
#   subscription_start_date  is_active  Monthly_Charge primary_device  \
# ...

# %%
df["Monthly_Charge"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9476 entries, 0 to 10299
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  9476 non-null   object
#  1   email                    9476 non-null   object
#  2   first_name               9476 non-null   object
#  3   last_name                9476 non-null   object
#  4   age                      9476 non-null   int64
#  5   gender                   9476 non-null   object
#  6   country                  9476 non-null   object
#  7   state_province           9476 non-null   object
#  8   city                     9476 non-null   object
#  9   subscription_plan        9476 non-null   object
#  10  subscription_start_date  9476 non-null   object
#  11  is_active                9476 non-null   bool
#  12  Monthly_Charge           9476 non-null   float64
#  13  primary_device           9476 non-null   object
# ...

# %%
median_h=df["household_size"].median()
mean_h=df["household_size"].mean()
print(median_h)
print(mean_h)
# Out:
# 2.0
# 2.865174129353234

# %%
df["household_size"]=df["household_size"].fillna(median_h)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9476 entries, 0 to 10299
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  9476 non-null   object
#  1   email                    9476 non-null   object
#  2   first_name               9476 non-null   object
#  3   last_name                9476 non-null   object
#  4   age                      9476 non-null   int64
#  5   gender                   9476 non-null   object
#  6   country                  9476 non-null   object
#  7   state_province           9476 non-null   object
#  8   city                     9476 non-null   object
#  9   subscription_plan        9476 non-null   object
#  10  subscription_start_date  9476 non-null   datetime64[ns]
#  11  is_active                9476 non-null   bool
#  12  Monthly_Charge           9476 non-null   float64
#  13  primary_device           9476 non-null   object
# ...

# %%
df["subscription_start_date"]=pd.to_datetime(df["subscription_start_date"])

# %%
df["created_at"] = pd.to_datetime(df["created_at"])

# %%
df.head(12)
# Out:
#        user_id                        email first_name  last_name  age  \
# 0   user_00001     figueroajohn@example.org      Erica      Garza   43
# 1   user_00002        blakeerik@example.com     Joshua    Bernard   38
# 2   user_00003          smiller@example.net    Barbara   Williams   32
# 3   user_00004    mitchellclark@example.com    Chelsea   Ferguson   11
# 4   user_00005        richard13@example.net      Jason     Foster   21
# 5   user_00006        jeffrey28@example.com    Katelyn  Hernandez   43
# 7   user_00008  nathanielmartin@example.net      Carol      Smith   35
# 8   user_00009      donnaarroyo@example.org    Allison     Brandt   24
# 9   user_00010    morganbrianna@example.org     Adrian      Perez   24
# 10  user_00011   kristenaguirre@example.org     Collin      Gomez   67
# 11  user_00012     jamesherrera@example.org     Isaiah     Wright   41
# 12  user_00013     richardolson@example.com   Franklin   Galloway   32
#
# ...

# %%
df["created_at"]=df["created_at"].dt.floor("s")

# %%
df["household_size"] = df["household_size"].astype(int)

# %% [markdown]
# Adding New Column "churn"

# %%
df["churn"] = df["is_active"].map({
    True: 0,
    False: 1
})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9476 entries, 0 to 10299
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  9476 non-null   object
#  1   email                    9476 non-null   object
#  2   first_name               9476 non-null   object
#  3   last_name                9476 non-null   object
#  4   age                      9476 non-null   int64
#  5   gender                   9476 non-null   object
#  6   country                  9476 non-null   object
#  7   state_province           9476 non-null   object
#  8   city                     9476 non-null   object
#  9   subscription_plan        9476 non-null   object
#  10  subscription_start_date  9476 non-null   datetime64[ns]
#  11  is_active                9476 non-null   bool
#  12  Monthly_Charge           9476 non-null   float64
#  13  primary_device           9476 non-null   object
# ...

# %%
df.loc[df["is_active"]==False,["is_active","churn"]]
# Out:
#        is_active  churn
# 2          False      1
# 14         False      1
# 24         False      1
# 49         False      1
# 50         False      1
# ...          ...    ...
# 10266      False      1
# 10271      False      1
# 10284      False      1
# 10291      False      1
# 10296      False      1
#
# [1393 rows x 2 columns]

# %% [markdown]
# Saving Cleaned Data

# %%
df.to_csv("C:/Users/samar/Desktop/samarth15/OTT platform customer churn prediction/Data/Cleaned Data/users_cleaned.csv",index=False)
